# %%
import pandas as pd
import glob
from IPython.display import HTML
import numpy as np
#.reset_index(drop = True)
import sys
import matplotlib.pyplot as plt
#import seaborn as sns
#%matplotlib inline 
pd.options.display.max_colwidth = None
from Clases.ConnMysql import ConnectMySQL
from Clases.CatalogUtility import CatalogUtility
from dotenv import load_dotenv
import os
#%run /ProyectoTx/examenkavak/Clases/ConnMysql.py

# %%
# %run /ProyectoTx/examenkavak/Clases/ConnMysql.py
# %run /ProyectoTx/examenkavak/Clases/Catalogue.py
# %run /ProyectoTx/examenkavak/Clases/CatalogUtility.py

# %%
#objConMysql = ConnectMySQL( host, bd, user, password, port )

# %%
path_work  =  os.getcwd()
load_dotenv( os.path.join( path_work ,'Clases/envs.txt' ) )

host       =  os.getenv('HOST_MYSQL')
bd         =  os.getenv('DB_MYSQL')
user       =  os.getenv('USER_MYSQL')
password   =  os.getenv('PASSWORD_MYSQL')
port       =  os.getenv('PORT_MYSQL')

objConMysql = ConnectMySQL( host, bd, user, password, port )

lista_culumns_cat   =  ['ESTADO','GIRO','CATALOGO','CATEGORIA','MARCA']
dic_columns_id      =  {"df_ESTADO":["ESTADO"],"df_GIRO":["GIRO"],"df_CATALOGO":["CATALOGO"],"df_CATEGORIA":["CATEGORIA"],"df_MARCA":["MARCA"]}
dic_columns_vs_cat  =  {"df_ESTADO":["ESTADO"],"df_GIRO":["GIRO"],"df_CATALOGO":["CATALOGO"],"df_CATEGORIA":["CATEGORIA"],"df_MARCA":["MARCA"]}
dic_columns_cat     =  {"df_ESTADO":["ID_ESTADO","ESTADO"],"df_GIRO":["ID_GIRO","GIRO"],"df_CATALOGO":["ID_CATALOGO","CATALOGO"],"df_CATEGORIA":["ID_CATEGORIA","CATEGORIA"],"df_MARCA":["ID_MARCA","MARCA"]}
  
path_data   =  os.path.join( path_work, 'Data' ) # "/ProyectoTx/examenkavak/data/"
headers     =  ["PRODUCTO","PRESENTACION","MARCA","CATEGORIA","CATALOGO","PRECIO","FECHAREGISTRO","CADENACOMERCIAL","GIRO","NOMBRECOMERCIAL","DIRECCION","ESTADO","MUNICIPIO","LATITUD","LONGITUD"]
files       =  glob.glob( os.path.join( path_data, "*.csv" ) , recursive = True)
df_union    =  pd.DataFrame( [] , columns  =  headers  )
# Out:
# 192.168.200.6 dw_qqprm root 3310 root mysql+mysqlconnector://root:root@192.168.200.6:3310/dw_qqprm

# %%
files
# Out:
# ['D:\\ProyectoTx\\examenkavak\\Data\\01-2023_01.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\01-2023_02.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\02-2023_01.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\02-2023_02.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\03-2023_01.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\03-2023_02.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\04-2023_01.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\04-2023_02.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\05-2023_01.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\05-2023_02.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\06-2023_01.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\06-2023_02.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\07-2023_01.csv',
#  'D:\\ProyectoTx\\examenkavak\\Data\\07-2023_02.csv']

# %% [markdown]
# ### Lectura  de datos local

# %%
for f in files:
        pivote= pd.DataFrame([])
        pivote = pd.read_csv(f,header = None)
        pivote.columns = headers
        df_union = pd.concat([df_union, pivote], ignore_index=True)
    
df_union.shape
# Out:
# (8745162, 15)

# %%
#df_union.head(4)

# %%
#df_union.isnull().sum()

# %%
#df_union_back = df_union.copy()

# %%
df_union['LATITUD'] = df_union['LATITUD'].fillna(0.000000)

# %%
df_union['LONGITUD'] = df_union['LONGITUD'].fillna(0.000000)

# %% [markdown]
# ### Actualizacion de catalogos o tablas tipo catalogo

# %%
#objConMysql = ConnectMySQL( host, bd, user, password, port )

# %%
objCat      = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
# Out:
# ['ESTADO', 'GIRO', 'CATALOGO', 'CATEGORIA', 'MARCA']
# {'df_ESTADO': ['ESTADO'], 'df_GIRO': ['GIRO'], 'df_CATALOGO': ['CATALOGO'], 'df_CATEGORIA': ['CATEGORIA'], 'df_MARCA': ['MARCA']}
# {'df_ESTADO': ['ESTADO'], 'df_GIRO': ['GIRO'], 'df_CATALOGO': ['CATALOGO'], 'df_CATEGORIA': ['CATEGORIA'], 'df_MARCA': ['MARCA']}
# {'df_ESTADO': ['ID_ESTADO', 'ESTADO'], 'df_GIRO': ['ID_GIRO', 'GIRO'], 'df_CATALOGO': ['ID_CATALOGO', 'CATALOGO'], 'df_CATEGORIA': ['ID_CATEGORIA', 'CATEGORIA'], 'df_MARCA': ['ID_MARCA', 'MARCA']}

# %%
objCat._update( df_union )
# Out:
# PRODUCTO            object
# PRESENTACION        object
# MARCA               object
# CATEGORIA           object
# CATALOGO            object
# PRECIO             float64
# FECHAREGISTRO       object
# CADENACOMERCIAL     object
# GIRO                object
# NOMBRECOMERCIAL     object
# DIRECCION           object
# ESTADO              object
# MUNICIPIO           object
# LATITUD            float64
# LONGITUD           float64
# dtype: object
# clave ESTADO ....valor:                   ESTADO
# 0         AGUASCALIENTES
# 1        BAJA CALIFORNIA
# 2    BAJA CALIFORNIA SUR
# 3               CAMPECHE
# 4                CHIAPAS
# 5              CHIHUAHUA
# 6       CIUDAD DE MÉXICO
# 7   COAHUILA DE ZARAGOZA
# 8                DURANGO
# 9       ESTADO DE MÉXICO
# 10            GUANAJUATO
# 11              GUERRERO
# 12               HIDALGO
# 13               JALISCO
# 14   MICHOACÁN DE OCAMPO
# 15               MORELOS
# 16            NUEVO LEÓN
# 17                OAXACA
# ...

# %% [markdown]
# ### Actualizacion del catalogo municipio

# %%
df_municipio = df_union[['ESTADO','MUNICIPIO']].groupby(by=['ESTADO','MUNICIPIO'],as_index=False).first().sort_values(by=['ESTADO','MUNICIPIO']).reset_index(drop=True)

# %%
df_municipio.head(3)
# Out:
#                 ESTADO       MUNICIPIO
# 0       AGUASCALIENTES  AGUASCALIENTES
# 1      BAJA CALIFORNIA         TIJUANA
# 2  BAJA CALIFORNIA SUR          LA PAZ

# %%
lista_culumns_cat   =  ['ESTADO']
dic_columns_id      =  {"df_ESTADO":["ESTADO"]}
dic_columns_vs_cat  =  {"df_ESTADO":["ESTADO"]}
dic_columns_cat     =  {"df_ESTADO":["ID_ESTADO","ESTADO"]}

# %%
objCat2      = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
# Out:
# ['ESTADO']
# {'df_ESTADO': ['ESTADO']}
# {'df_ESTADO': ['ESTADO']}
# {'df_ESTADO': ['ID_ESTADO', 'ESTADO']}

# %%
df_municipio_ids = objCat2._update_dataframe_with_ids(df_municipio)
# Out:
# tipo de dato name_cat es una:  <class 'list'>
# query: Select ID_ESTADO,ESTADO from ESTADO;
# column_names: ['ID_ESTADO', 'ESTADO']
# pivote:--------
# (30, 2)
# entro a no rows
# rows []
# <class 'pandas.core.frame.DataFrame'>
# (30, 2)
# 'df_result'
#     ID_ESTADO                ESTADO
# 0           1        AGUASCALIENTES
# 1           2       BAJA CALIFORNIA
# 2           3   BAJA CALIFORNIA SUR
# 3           4              CAMPECHE
# 4           5               CHIAPAS
# 5           6             CHIHUAHUA
# 6           7      CIUDAD DE MÉXICO
# 7           8  COAHUILA DE ZARAGOZA
# 8           9               DURANGO
# 9          10      ESTADO DE MÉXICO
# 10         11            GUANAJUATO
# 11         12              GUERRERO
# 12         13               JALISCO
# 13         14   MICHOACÁN DE OCAMPO
# 14         15               MORELOS
# 15         16            NUEVO LEÓN
# 16         17                OAXACA
# 17         18                PUEBLA
# ...

# %%
df_municipio_ids = df_municipio_ids[['MUNICIPIO','ID_ESTADO']]

# %%
df_municipio_ids
# Out:
#                 MUNICIPIO  ID_ESTADO
# 0          AGUASCALIENTES          1
# 1                 TIJUANA          2
# 2                  LA PAZ          3
# 3                CAMPECHE          4
# 4        TUXTLA GUTIÉRREZ          5
# ..                    ...        ...
# 68                 MÉRIDA         28
# 69              GUADALUPE         29
# 70              ZACATECAS         29
# 71  MINERAL DE LA REFORMA         30
# 72        PACHUCA DE SOTO         30
#
# [73 rows x 2 columns]

# %%
# %run /ProyectoTx/examenkavak/Clases/Catalogue.py

# %%
lista_culumns_cat   =  ['MUNICIPIO'] # columnas de mi dataframe reult al que hay que sacar los valores unicos
dic_columns_id      =  {"df_MUNICIPIO":["MUNICIPIO","ID_ESTADO"]} # columnas id para hacer mach
dic_columns_vs_cat  =  {"df_MUNICIPIO":["MUNICIPIO"]} # para ver de que tbla viene el dataframe
dic_columns_cat     =  {"df_MUNICIPIO":["ID_MUNICIPIO","MUNICIPIO","ID_ESTADO"]} # para la consulta

# %%
objCat3      = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
objCat3._update( df_municipio_ids )
# Out:
# ['MUNICIPIO']
# {'df_MUNICIPIO': ['MUNICIPIO', 'ID_ESTADO']}
# {'df_MUNICIPIO': ['MUNICIPIO']}
# {'df_MUNICIPIO': ['ID_MUNICIPIO', 'MUNICIPIO', 'ID_ESTADO']}
# MUNICIPIO    object
# ID_ESTADO     int64
# dtype: object
# clave MUNICIPIO ....valor:                MUNICIPIO  ID_ESTADO
# 0     ACAPULCO DE JUÁREZ         12
# 1         AGUASCALIENTES          1
# 2                APIZACO         26
# 3               ATIZAPÁN         10
# 4   ATIZAPÁN DE ZARAGOZA         10
# ..                   ...        ...
# 68            XOCHIMILCO          7
# 69             ZACATECAS         29
# 70               ZAPOPAN         13
# 71          ZINACANTEPEC         10
# 72        ÁLVARO OBREGÓN          7
#
# [73 rows x 2 columns] tipovalor: <class 'pandas.core.frame.DataFrame'>
# imprimiendo dic_dfs_cat_result: {'df_MUNICIPIO':                MUNICIPIO  ID_ESTADO
# 0     ACAPULCO DE JUÁREZ         12
# 1         AGUASCALIENTES          1
# 2                APIZACO         26
# ...

# %% [markdown]
# # Actualizar cadena comercial

# %%
df_cadenacomercial = df_union[['CADENACOMERCIAL','GIRO']].groupby(by=['CADENACOMERCIAL','GIRO'],as_index=False).first().sort_values(by=['CADENACOMERCIAL','GIRO']).reset_index(drop=True)

# %%
lista_culumns_cat   =  ['GIRO']
dic_columns_id      =  {"df_GIRO":["GIRO"]}
dic_columns_vs_cat  =  {"df_GIRO":["GIRO"]}
dic_columns_cat     =  {"df_GIRO":["ID_GIRO","GIRO"]}

# %%
objCat4      = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
# Out:
# ['GIRO']
# {'df_GIRO': ['GIRO']}
# {'df_GIRO': ['GIRO']}
# {'df_GIRO': ['ID_GIRO', 'GIRO']}

# %%
df_cadenacomercial_ids = objCat4._update_dataframe_with_ids(df_cadenacomercial)
# Out:
# tipo de dato name_cat es una:  <class 'list'>
# query: Select ID_GIRO,GIRO from GIRO;
# column_names: ['ID_GIRO', 'GIRO']
# pivote:--------
# (16, 2)
# entro a no rows
# rows []
# <class 'pandas.core.frame.DataFrame'>
# (16, 2)
# 'df_result'
#     ID_GIRO                                   GIRO
# 0         1  SUPERMERCADO / TIENDA DE AUTOSERVICIO
# 1         2                               MERCADOS
# 2         3                 TIENDA DE CONVENIENCIA
# 3         4                 TIENDA DEPARTAMENTALES
# 4         5                           TORTILLERÍAS
# 5         6            TIENDA DE ELECTRODOMÉSTICOS
# 6         7                              FARMACIAS
# 7         8                            JUGUETERÍAS
# 8         9                      CENTRAL DE ABASTO
# 9        10                            PESCADERÍAS
# 10       11                             PANADERÍAS
# 11       12                             PAPELERÍAS
# 12       13                              UNIFORMES
# ...

# %%
df_cadenacomercial_ids = df_cadenacomercial_ids[['CADENACOMERCIAL','ID_GIRO']]

# %%
df_cadenacomercial_ids
# Out:
#            CADENACOMERCIAL  ID_GIRO
# 0                  ALSUPER        1
# 1     ALSUPER FRESH MARKET        1
# 2            ALSUPER STORE        1
# 3                BENAVIDES        1
# 4           BODEGA AURRERA        1
# ..                     ...      ...
# 255      ZAPATERIA LA LUNA       16
# 256     ZAPATERIA LA PERLA       16
# 257        ZAPATERIA PAKAR       16
# 258             ZAPATERIAS       16
# 259  ZAPATERIAS 3 HERMANOS       16
#
# [260 rows x 2 columns]

# %%
lista_culumns_cat   =  ['CADENACOMERCIAL'] # columnas de mi dataframe reult al que hay que sacar los valores unicos
dic_columns_id      =  {"df_CADENACOMERCIAL":["CADENACOMERCIAL","ID_GIRO"]} # columnas id para hacer mach
dic_columns_vs_cat  =  {"df_CADENACOMERCIAL":["CADENACOMERCIAL"]} # para ver de que tbla viene el dataframe
dic_columns_cat     =  {"df_CADENACOMERCIAL":["ID_CADENACOMERCIAL","CADENACOMERCIAL","ID_GIRO"]} # para la consulta

# %%
objCat5      = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
objCat5._update( df_cadenacomercial_ids )
# Out:
# ['CADENACOMERCIAL']
# {'df_CADENACOMERCIAL': ['CADENACOMERCIAL', 'ID_GIRO']}
# {'df_CADENACOMERCIAL': ['CADENACOMERCIAL']}
# {'df_CADENACOMERCIAL': ['ID_CADENACOMERCIAL', 'CADENACOMERCIAL', 'ID_GIRO']}
# CADENACOMERCIAL    object
# ID_GIRO             int64
# dtype: object
# clave CADENACOMERCIAL ....valor:                      CADENACOMERCIAL  ID_GIRO
# 0                           7 ELEVEN        3
# 1    ABARROTERA GUADALUPANA (FRUTAS)        3
# 2               ABARROTERA MONTERREY        3
# 3                 ABARROTERA SANCHEZ        3
# 4      ABARROTES SUPER CABRERA CLASS        3
# ..                               ...      ...
# 255                ZAPATERIA LA LUNA       16
# 256               ZAPATERIA LA PERLA       16
# 257                  ZAPATERIA PAKAR       16
# 258                       ZAPATERIAS       16
# 259            ZAPATERIAS 3 HERMANOS       16
#
# [260 rows x 2 columns] tipovalor: <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# # Actualizando Comercial

# %%
#from pandasql import sqldf
#pysqldf = lambda q: sqldf(q, locals()) 
#q = """
#        SELECT ID_MUNICIPIO,MUNICIPIO,ESTADO FROM df_tbl_municipio AS A
#        INNER JOIN df_tbl_estado AS B
#        ON A.ID_ESTADO = B.ID_ESTADO
#        ORDER BY 1;
#            """
#result = sqldf(q)

# %% [markdown]
# #### Obtener ID_MUNICIPIO con base a el MUNICIPIO Y ESTADO

# %%
q = """ SELECT ID_MUNICIPIO,MUNICIPIO,ESTADO FROM MUNICIPIO AS A
INNER JOIN ESTADO AS B
ON A.ID_ESTADO = B.ID_ESTADO
ORDER BY 1"""

search_query = q
objConMysql.set_query(search_query )
objConMysql.get_query()
df_tbl_municipio_estado = objConMysql.extract_data_all(batch_size=10000)
# Out:
# column_names: ['ID_MUNICIPIO', 'MUNICIPIO', 'ESTADO']
# pivote:--------
# (73, 3)
# entro a no rows
# rows []

# %%
#df_union.shape

# %%
df_tbl_municipio_estado.head(2)
# Out:
#    ID_MUNICIPIO           MUNICIPIO          ESTADO
# 0             1  ACAPULCO DE JUÁREZ        GUERRERO
# 1             2      AGUASCALIENTES  AGUASCALIENTES

# %%
lista_culumns_cat   =  ['JOIN'] # columnas de mi dataframe reult al que hay que sacar los valores unicos
dic_columns_id      =  {"df_JOIN":["MUNICIPIO","ESTADO"]} # columnas id para hacer mach
dic_columns_vs_cat  =  {"df_JOIN":["MUNICIPIO_ESTADO"]} # para ver de que tbla viene el dataframe
dic_columns_cat     =  {"df_JOIN":["ID_MUNICIPIO","MUNICIPIO","ID_ESTADO"]} # para la consulta

# %%
dic_dfs_cat_up_tab={}
dic_dfs_cat_up_tab["df_JOIN"] =  df_tbl_municipio_estado

# %%
dic_dfs_cat_up_tab
# Out:
# {'df_JOIN':     ID_MUNICIPIO             MUNICIPIO            ESTADO
#  0              1    ACAPULCO DE JUÁREZ          GUERRERO
#  1              2        AGUASCALIENTES    AGUASCALIENTES
#  2              3               APIZACO          TLAXCALA
#  3              4              ATIZAPÁN  ESTADO DE MÉXICO
#  4              5  ATIZAPÁN DE ZARAGOZA  ESTADO DE MÉXICO
#  ..           ...                   ...               ...
#  68            69            XOCHIMILCO  CIUDAD DE MÉXICO
#  69            70             ZACATECAS         ZACATECAS
#  70            71               ZAPOPAN           JALISCO
#  71            72          ZINACANTEPEC  ESTADO DE MÉXICO
#  72            73        ÁLVARO OBREGÓN  CIUDAD DE MÉXICO
#
#  [73 rows x 3 columns]}

# %%
objCat6          = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
df_union_ids = objCat6._update_dataframe_with_ids(df_union, dic_dfs_cat_up_tab)
# Out:
# ['JOIN']
# {'df_JOIN': ['MUNICIPIO', 'ESTADO']}
# {'df_JOIN': ['MUNICIPIO_ESTADO']}
# {'df_JOIN': ['ID_MUNICIPIO', 'MUNICIPIO', 'ID_ESTADO']}
#   PRODUCTO                                   PRESENTACION MARCA     CATEGORIA  \
# 0  A.S.COR  FRASCO GOTERO 24 ML. 1.000 G., SOLUCION GOTAS   S/M  MEDICAMENTOS
#
#        CATALOGO  PRECIO FECHAREGISTRO CADENACOMERCIAL  \
# 0  MEDICAMENTOS   389.0    2023-01-02    MEGA SORIANA
#
#                                     GIRO  \
# 0  SUPERMERCADO / TIENDA DE AUTOSERVICIO
#
#                         NOMBRECOMERCIAL  \
# 0  MEGA SORIANA SUCURSAL AGUASCALIENTES
#
#                                                                            DIRECCION  \
# 0  AGUASCALIENTES NTE. 802, ESQ. BLVD. A ZACATECAS, COL. TROJES DE ALONSO, CP. 20116
#
#            ESTADO       MUNICIPIO    LATITUD    LONGITUD
# 0  AGUASCALIENTES  AGUASCALIENTES  21.916001 -102.290779
# ...

# %% [markdown]
# ##### Obtener ID_CADENACOMERCIAL con base a CADENACOEMRCIAL Y GIRO

# %%
search_query = """SELECT ID_CADENACOMERCIAL,CADENACOMERCIAL,GIRO FROM CADENACOMERCIAL AS A
INNER JOIN GIRO AS B
ON A.ID_GIRO = B.ID_GIRO
ORDER BY 1 """
objConMysql.set_query(search_query )
objConMysql.get_query()
# Out:
# 'SELECT ID_CADENACOMERCIAL,CADENACOMERCIAL,GIRO FROM CADENACOMERCIAL AS A\nINNER JOIN GIRO AS B\nON A.ID_GIRO = B.ID_GIRO\nORDER BY 1 '

# %%
df_join_tbl_cadenacomercial_giro = objConMysql.extract_data_all(batch_size=10000)
# Out:
# column_names: ['ID_CADENACOMERCIAL', 'CADENACOMERCIAL', 'GIRO']
# pivote:--------
# (260, 3)
# entro a no rows
# rows []

# %%
df_union_ids.shape
# Out:
# (8745162, 14)

# %%
lista_culumns_cat   =  ['JOIN'] # columnas de mi dataframe reult al que hay que sacar los valores unicos
dic_columns_id      =  {"df_JOIN":["CADENACOMERCIAL","GIRO"]} # columnas id para hacer mach
dic_columns_vs_cat  =  {"df_JOIN":["CADENACOMERCIAL_GIRO"]} # para ver de que tbla viene el dataframe
dic_columns_cat     =  {"df_JOIN":["ID_MUNICIPIO","MUNICIPIO","ID_ESTADO"]} # para la consulta

dic_dfs_cat_up_tab={}
dic_dfs_cat_up_tab["df_JOIN"] =  df_join_tbl_cadenacomercial_giro

objCat7          = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
df_union_ids = objCat7._update_dataframe_with_ids(df_union_ids, dic_dfs_cat_up_tab)
# Out:
# ['JOIN']
# {'df_JOIN': ['CADENACOMERCIAL', 'GIRO']}
# {'df_JOIN': ['CADENACOMERCIAL_GIRO']}
# {'df_JOIN': ['ID_MUNICIPIO', 'MUNICIPIO', 'ID_ESTADO']}
#    ID_MUNICIPIO PRODUCTO           PRESENTACION  MARCA  \
# 0             1   ACEITE  BOTELLA 1 LT. VEGETAL  1-2-3
#
#                            CATEGORIA CATALOGO  PRECIO FECHAREGISTRO  \
# 0  ACEITES Y GRASAS VEG. COMESTIBLES  BASICOS    57.5    2023-01-10
#
#         CADENACOMERCIAL                                   GIRO  \
# 0  HIPERMERCADO SORIANA  SUPERMERCADO / TIENDA DE AUTOSERVICIO
#
#                                  NOMBRECOMERCIAL  \
# 0  SORIANA HIPER SUCURSAL ACAPULCO COSTERA (274)
#
#                                                                                                 DIRECCION  \
# 0  COSTERA MIGUEL ALEMAN 240, ENTRE JUAN S. CANO Y GABRIEL AVILES, COL. FRACCIONAMIENTO HORNOS, CP. 39350
#
#      LATITUD  LONGITUD
# 0  16.858598 -99.89027
# ...

# %%
df_union_ids.rename(columns={"NOMBRECOMERCIAL":"COMERCIAL","FECHAREGISTRO":"FECHA_REGISTRO"}, inplace= True)

# %%
df_union_ids.shape
# Out:
# (8745162, 13)

# %%
#df_union_ids['LATITUD'].fillna(0.0,inplace=True)
#df_union_ids['LONGITUD'].fillna(0.0,inplace=True)

# %%
#df_comercial_unique['LATITUD'] = df_comercial_unique['LATITUD'].round(5)
#df_comercial_unique['LONGITUD'] = df_comercial_unique['LONGITUD'].round(5)

# %%
def formatear_valor(valor):
    if pd.notna(valor):
        return '{:.6f}'.format(valor)
    else:
        return valor

# %%
# Aplicar la función a la columna LATITUD
df_union_ids['LATITUD'] = df_union_ids['LATITUD'].map(lambda x: formatear_valor(x))
df_union_ids['LONGITUD'] = df_union_ids['LONGITUD'].map(lambda x: formatear_valor(x))

# %%
df_union_ids[['LATITUD', 'LONGITUD']] = df_union_ids[['LATITUD', 'LONGITUD']].astype(str)

# %%
df_comercial_unique = df_union_ids[["COMERCIAL","DIRECCION","ID_MUNICIPIO","LATITUD","LONGITUD","ID_CADENACOMERCIAL"]].reset_index(drop=True)

# %%
df_comercial_unique.shape
# Out:
# (8745162, 6)

# %%
df_comercial_unique.sample(200).sort_values(by='LATITUD')
# Out:
#                                      COMERCIAL  \
# 5375276             MERCADO PUBLICO 5 DE  MAYO
# 1957985       CHEDRAUI SUCURSAL TUXTLA CRYSTAL
# 4438468         MEGA SORIANA SUCURSAL LA DIANA
# 3760231    SORIANA HIPER SUCURSAL OAXACA (105)
# 5218801         MERCADO PUBLICO TABASCO AVANZA
# ...                                        ...
# 7909046     WALMART SUCURSAL TIJUANA HIPODROMO
# 1214208                   CALIMAX SUCURSAL RIO
# 3961982             SORIANA HIPER SUCURSAL RIO
# 6480005  SORIANA SUPER SUCURSAL LIBERTAD (377)
# 6711685               LEY SUCURSAL OTAY (1051)
#
#                                                                                               DIRECCION  \
# 5375276        CALLE 4 NORTE S/N, ENTRE CALLE 11 PONIENTE  Y CALLE 12 PONIENTE, COL. HIDALGO, CP. 29040
# 1957985               BELISARIO DOMINGUEZ 1691, ENTRE BUGAMBILIAS Y CIRO FERRERA, COL. TERAN, CP. 29000
# ...

# %%
df_comercial_unique = df_comercial_unique.groupby(by=["COMERCIAL","DIRECCION","ID_MUNICIPIO","LATITUD","LONGITUD","ID_CADENACOMERCIAL"],dropna=False, as_index=False).first()

# %%
df_comercial_unique.shape
# Out:
# (1992, 6)

# %%
df_comercial_unique.isnull().sum()
# Out:
# COMERCIAL             0
# DIRECCION             0
# ID_MUNICIPIO          0
# LATITUD               0
# LONGITUD              0
# ID_CADENACOMERCIAL    0
# dtype: int64

# %%
#df_comercial_unique_prueba = df_comercial_unique.iloc[0:8]

# %%
#nulos = df_comercial_unique[(df_comercial_unique['LATITUD'].isnull()) | (df_comercial_unique['LONGITUD'].isnull()) ]
#nulos = df_comercial_unique[(df_comercial_unique['LATITUD']== '0.000000') | (df_comercial_unique['LONGITUD']== '0.000000') ]

# %%
#df_comercial_unique_prueba = pd.concat([df_comercial_unique_prueba,nulos], ignore_index=True)

# %%
#df_comercial_unique_prueba

# %%
df_comercial_unique.dtypes

# %% [markdown]
# ### Actualizando Catalogo COMERCIAL

# %%
q = """ SELECT * FROM COMERCIAL"""

search_query = q
objConMysql.set_query(search_query )
objConMysql.get_query()
df_tbl_comercial = objConMysql.extract_data_all(batch_size=10000)
df_tbl_comercial[['LATITUD', 'LONGITUD']] = df_tbl_comercial[['LATITUD', 'LONGITUD']].astype(str)
#df_tbl_comercial = df_tbl_comercial.replace({'0.000000': '0.0'})
# Out:
# column_names: ['ID_COMERCIAL', 'COMERCIAL', 'DIRECCION', 'ID_MUNICIPIO', 'LATITUD', 'LONGITUD', 'ID_CADENACOMERCIAL']
# pivote:--------
# (1992, 7)
# entro a no rows
# rows []

# %%
df_tbl_comercial
# Out:
#       ID_COMERCIAL                                      COMERCIAL  \
# 0                1                                       7 ELEVEN
# 1                2                         7 ELEVEN SUCUESAL 2097
# 2                3          7 ELEVEN SUCURSAL 549 AGUIRRE PEQUEÑO
# 3                4                 7 ELEVEN SUCURSAL PABLO NERUDA
# 4                5                7 ELEVEN SUCURSAL SIMÓN BOLÍVAR
# ...            ...                                            ...
# 1987          1988  ZAPATERIAS EL GRILLITO CANTOR SUCURSAL MATRIZ
# 1988          1989              ZAPATERIAS MONTSERRAT SUCURSAL 05
# 1989          1990                               ZAPATERIAS PAKAR
# 1990          1991                             ZORRO SUCURSAL ZQ6
# 1991          1992                                    ¡QUE POLLO!
#
#                                                                                                                          DIRECCION  \
# ...

# %%
lista_culumns_cat   =  ['COMERCIAL'] # columnas de mi dataframe reult al que hay que sacar los valores unicos
dic_columns_id      =  {"df_COMERCIAL":["COMERCIAL","DIRECCION","ID_MUNICIPIO","LATITUD","LONGITUD","ID_CADENACOMERCIAL"]} # columnas id para hacer mach
dic_columns_vs_cat  =  {"df_COMERCIAL":["COMERCIAL"]} # para ver de que tbla viene el dataframe
dic_columns_cat     =  {"df_COMERCIAL":["ID_COMERCIAL","COMERCIAL","DIRECCION","ID_MUNICIPIO","LATITUD","LONGITUD","ID_CADENACOMERCIAL"]} # para la consulta
objCat10     = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
dic_columns_modify={'float':['LATITUD','LONGITUD']}

dic_dfs_cat_tab_origen={}
dic_dfs_cat_tab_origen["df_COMERCIAL"] =  df_tbl_comercial

objCat10._update(df_comercial_unique,dic_dfs_cat_tab_origen,dic_columns_modify)
# Out:
# ['COMERCIAL']
# {'df_COMERCIAL': ['COMERCIAL', 'DIRECCION', 'ID_MUNICIPIO', 'LATITUD', 'LONGITUD', 'ID_CADENACOMERCIAL']}
# {'df_COMERCIAL': ['COMERCIAL']}
# {'df_COMERCIAL': ['ID_COMERCIAL', 'COMERCIAL', 'DIRECCION', 'ID_MUNICIPIO', 'LATITUD', 'LONGITUD', 'ID_CADENACOMERCIAL']}
# COMERCIAL             object
# DIRECCION             object
# ID_MUNICIPIO           int64
# LATITUD               object
# LONGITUD              object
# ID_CADENACOMERCIAL     int64
# dtype: object
# clave COMERCIAL ....valor:                                           COMERCIAL  \
# 0                                          7 ELEVEN
# 1                            7 ELEVEN SUCUESAL 2097
# 2             7 ELEVEN SUCURSAL 549 AGUIRRE PEQUEÑO
# 3                    7 ELEVEN SUCURSAL PABLO NERUDA
# 4                   7 ELEVEN SUCURSAL SIMÓN BOLÍVAR
# ...                                             ...
# 1987  ZAPATERIAS EL GRILLITO CANTOR SUCURSAL MATRIZ
# 1988              ZAPATERIAS MONTSERRAT SUCURSAL 05
# ...

# %% [markdown]
# ### Actualizando Tabla Producto

# %% [markdown]
# #### Obtener ID_MARCA, ID_CATEGORIA, ID_CATALOGO

# %%
lista_culumns_cat   =  ['MARCA','CATEGORIA','CATALOGO'] # columnas de mi dataframe reult al que hay que sacar los valores unicos
dic_columns_id      =  {"df_MARCA":["MARCA"],"df_CATEGORIA":["CATEGORIA"],"df_CATALOGO":["CATALOGO"]} # columnas id para hacer mach
dic_columns_vs_cat  =  {"df_MARCA":["MARCA"],"df_CATEGORIA":["CATEGORIA"],"df_CATALOGO":["CATALOGO"]} # para ver de que tbla viene el dataframe
dic_columns_cat     =  {"df_MARCA":["ID_MARCA","MARCA"],"df_CATEGORIA":["ID_CATEGORIA","CATEGORIA"],"df_CATALOGO":["ID_CATALOGO","CATALOGO"]} # para la consulta

# %%
objCat8          = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
df_union_ids     = objCat8._update_dataframe_with_ids(df_union_ids)
# Out:
# ['MARCA', 'CATEGORIA', 'CATALOGO']
# {'df_MARCA': ['MARCA'], 'df_CATEGORIA': ['CATEGORIA'], 'df_CATALOGO': ['CATALOGO']}
# {'df_MARCA': ['MARCA'], 'df_CATEGORIA': ['CATEGORIA'], 'df_CATALOGO': ['CATALOGO']}
# {'df_MARCA': ['ID_MARCA', 'MARCA'], 'df_CATEGORIA': ['ID_CATEGORIA', 'CATEGORIA'], 'df_CATALOGO': ['ID_CATALOGO', 'CATALOGO']}
# tipo de dato name_cat es una:  <class 'list'>
# query: Select ID_MARCA,MARCA from MARCA;
# column_names: ['ID_MARCA', 'MARCA']
# pivote:--------
# (1110, 2)
# entro a no rows
# rows []
# <class 'pandas.core.frame.DataFrame'>
# (1110, 2)
# 'df_result'
#       ID_MARCA                MARCA
# 0            1                  S/M
# 1            2                1-2-3
# 2            3                  AVE
# 3            4               CANOIL
# 4            5              CAPULLO
# ...        ...                  ...
# 1105      1106     PILOTO. FIFAFLEX
# 1106      1107  ZEBRA. GRIP. PENCIL
# 1107      1108          5 ESTRELLAS
# ...

# %%
df_union_ids.head(2)
# Out:
#    ID_CATALOGO  ID_CATEGORIA  ID_MARCA  ID_CADENACOMERCIAL  ID_MUNICIPIO  \
# 0            1             1         1                   9            21
# 1            1             1         1                   9            21
#
#     PRODUCTO                      PRESENTACION  PRECIO FECHA_REGISTRO  \
# 0   ACARBOSA    CAJA CON 30 TABLETAS DE 50 MG.   149.9     2023-01-04
# 1  ACICLOVIR  CAJA CON TUBO CON 5 GR. CREMA 5%    74.9     2023-01-04
#
#                           COMERCIAL  \
# 0  ALSUPER SUCURSAL DOMINGO ARRIETA
# 1  ALSUPER SUCURSAL DOMINGO ARRIETA
#
#                                                               DIRECCION  \
# 0  DOMINGO ARRIETA 1403, ENTRE GEMINIS Y TALPA, COL. JALISCO, CP. 34180
# 1  DOMINGO ARRIETA 1403, ENTRE GEMINIS Y TALPA, COL. JALISCO, CP. 34180
#
#      LATITUD     LONGITUD
# 0  24.003075  -104.662220
# 1  24.003075  -104.662220

# %%
df_union_ids.columns

# %%
df_union_ids.dtypes

# %% [markdown]
# #### Obtener ID_COMERCIAL

# %%
q = """ SELECT * FROM COMERCIAL"""

search_query = q
objConMysql.set_query(search_query )
objConMysql.get_query()
df_tbl_comercial = objConMysql.extract_data_all(batch_size=10000)
df_tbl_comercial[['LATITUD', 'LONGITUD']] = df_tbl_comercial[['LATITUD', 'LONGITUD']].astype(str)
#df_tbl_comercial = df_tbl_comercial.replace({'0.000000': '0.0'})
# Out:
# column_names: ['ID_COMERCIAL', 'COMERCIAL', 'DIRECCION', 'ID_MUNICIPIO', 'LATITUD', 'LONGITUD', 'ID_CADENACOMERCIAL']
# pivote:--------
# (1992, 7)
# entro a no rows
# rows []

# %%
df_tbl_comercial

# %%
lista_culumns_cat   =  ['JOIN'] # columnas de mi dataframe reult al que hay que sacar los valores unicos
dic_columns_id      =  {"df_JOIN":["COMERCIAL","DIRECCION","ID_MUNICIPIO","LATITUD","LONGITUD","ID_CADENACOMERCIAL"]} # columnas id para hacer mach
dic_columns_vs_cat  =  {"df_JOIN":["COMERCIAL"]} # para ver de que tbla viene el dataframe
dic_columns_cat     =  {"df_JOIN":["ID_COMERCIAL","COMERCIAL","DIRECCION","ID_MUNICIPIO","LATITUD","LONGITUD","ID_CADENACOMERCIAL"]} # para la consulta

dic_dfs_cat_up_tab={}
dic_dfs_cat_up_tab["df_JOIN"] =  df_tbl_comercial

objCat7          = CatalogUtility( objConMysql,  lista_culumns_cat,  dic_columns_id,  dic_columns_vs_cat,  dic_columns_cat  )
df_union_ids = objCat7._update_dataframe_with_ids(df_union_ids, dic_dfs_cat_up_tab)
# Out:
# ['JOIN']
# {'df_JOIN': ['COMERCIAL', 'DIRECCION', 'ID_MUNICIPIO', 'LATITUD', 'LONGITUD', 'ID_CADENACOMERCIAL']}
# {'df_JOIN': ['COMERCIAL']}
# {'df_JOIN': ['ID_COMERCIAL', 'COMERCIAL', 'DIRECCION', 'ID_MUNICIPIO', 'LATITUD', 'LONGITUD', 'ID_CADENACOMERCIAL']}
#    ID_CATALOGO  ID_CATEGORIA  ID_MARCA  ID_CADENACOMERCIAL  ID_MUNICIPIO  \
# 0            1             1         1                   9            21
#
#    PRODUCTO                    PRESENTACION  PRECIO FECHA_REGISTRO  \
# 0  ACARBOSA  CAJA CON 30 TABLETAS DE 50 MG.   149.9     2023-01-04
#
#                           COMERCIAL  \
# 0  ALSUPER SUCURSAL DOMINGO ARRIETA
#
#                                                               DIRECCION  \
# 0  DOMINGO ARRIETA 1403, ENTRE GEMINIS Y TALPA, COL. JALISCO, CP. 34180
#
#      LATITUD     LONGITUD
# 0  24.003075  -104.662220
# ...

# %%
df_union_ids = df_union_ids[["PRODUCTO","PRESENTACION","ID_MARCA","ID_CATEGORIA","ID_CATALOGO","PRECIO","FECHA_REGISTRO","ID_COMERCIAL"]]

# %%
df_union_ids.shape
# Out:
# (8745162, 8)

# %%
df_union_ids
# Out:
#               PRODUCTO                        PRESENTACION  ID_MARCA  \
# 0        SUEROS ORALES           BOTELLA 625 ML. SABOR UVA       268
# 1        SUEROS ORALES           BOTELLA 625 ML. SABOR UVA       268
# 2        SUEROS ORALES           BOTELLA 625 ML. SABOR UVA       268
# 3        SUEROS ORALES           BOTELLA 625 ML. SABOR UVA       268
# 4        SUEROS ORALES           BOTELLA 625 ML. SABOR UVA       268
# ...                ...                                 ...       ...
# 8745157    CARNE POLLO  1 KG. GRANEL. PIERNA O PIERNA BATE         1
# 8745158    CARNE POLLO  1 KG. GRANEL. PIERNA O PIERNA BATE         1
# 8745159    CARNE POLLO  1 KG. GRANEL. PIERNA O PIERNA BATE         1
# 8745160    CARNE POLLO  1 KG. GRANEL. PIERNA O PIERNA BATE         1
# 8745161    CARNE POLLO  1 KG. GRANEL. PIERNA O PIERNA BATE         1
#
#          ID_CATEGORIA  ID_CATALOGO  PRECIO FECHA_REGISTRO  ID_COMERCIAL
# ...

# %%
objConMysql.load_data_chemy_masive(df_union_ids,'PRODUCTO')
