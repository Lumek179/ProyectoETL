# %%
import os
from dotenv import load_dotenv
load_dotenv(os.path.join( os.getcwd(),'envs.txt'))
import pandas as pd
from CustomException import CustomException
from CatalogUtility import CatalogUtility
from sqlalchemy import create_engine, Table, MetaData
from sqlalchemy.orm import sessionmaker
from sqlalchemy.exc import SQLAlchemyError

class ConnectMySQL():
    
    def __init__(self, host=os.getenv('HOST_MYSQL'),bd=os.getenv('DB_MYSQL'),user=os.getenv('USER_MYSQL'),password=os.getenv('PASSWORD_MYSQL'),port=os.getenv('PORT_MYSQL')):
    
        self.host               =  host
        self.bd                 =  bd
        self.user               =  user
        self.port               =  port
        self.password           =  password
        self.string_conn        =  f"mysql+mysqlconnector://{self.user}:{self.password}@{self.host}:3310/{self.bd}"
        #"mysql://{0}:{1}@{2}:{3}/{4}?charset=utf8".format(user, password, host, port, database)
        self.metadata = MetaData()
        self.batch_size     = 10
        print(self.host , self.bd, self.user, self.port, self.password ,self.string_conn )
        try:
            self.engine      =  create_engine(self.string_conn)
        except Exception as e:
            raise CustomException('Error al crear el engine',e)   

    ## Función de conexión a MySQL
    def create_engine(self):
        try:
            self.engine      =  create_engine(self.string_conn)
            #return create_engine(self.string_conn)   # este valor si quiero hacer multiples engine lo puedo descomentar y modificar
        except Exception as e:
            raise CustomException('Error al conectar con la base de datos',e) 
        
    def set_query(  self,  search_query ):
        self.__query  =  search_query
        
    def get_query(self):
        return self.__query
    
    def set_batch(  self,  batch_size ):
        self.batch_size   =  batch_size
        
    def get_batch(self):
        return self.batch_size 
    
    def generar_query_insert(self,table, columns):
        """
        Genera dinámicamente un query de inserción para una tabla dada y una lista de columnas.

        Args:
        - tabla: nombre de la tabla en la que se van a insertar los datos.
        - columnas: lista de nombres de columnas en la tabla.

        Returns:
        - query: query de inserción generado dinámicamente.
        """
        num_columns = len(columns)
        columns_str = ', '.join(columns)
        values_str = ', '.join(['%s'] * num_columns)
        self.__query = f"INSERT INTO {table} ({columns_str}) VALUES ({values_str})"
    
    
    def close_connect(self):  
        try:
            self.__conn.close()
        except Exception as e:
            raise CustomException('Error al cerrar la conexión con la base de datos',e)  
  
            
    def extract_data(self):
        #self.create_engine()
        df  = pd.read_sql(self.__query , con=self.engine.connect() ) 
        return df
    
    def load_data(self,df, tbl_name):
        pass
        #df.to_sql(tbl_name, self.engine , if_exists='replace')
     
    def load_data_chemy(self,df,name_table_dest):
        Session = sessionmaker(bind=self.engine)
        table_dest = Table(name_table_dest, self.metadata , autoload=True, autoload_with=self.engine)
        print(table_dest)
        try:
            datos = df.to_dict(orient='records')
            # Insertar datos utilizando la sesión
            with Session() as se:
                se.execute(table_dest.insert(), datos)
                se.commit()  # Confirmar la transacción
                print(ab)
        except SQLAlchemyError as e:
            print("Error:", e)
            if se:
                se.rollback()  # Revertir la transacción en caso de error  
        except Exception as e:
            print("Error:", e)

    def load_data_chemy_connect(self,df,name_table_dest):
        table_dest = Table(name_table_dest, self.metadata , autoload=True, autoload_with=self.engine)
        print(table_dest)
        try:
            datos = df.to_dict(orient='records')  
            with self.engine.connect() as conn:
                conn.execute(table_dest.insert(), datos)
        except SQLAlchemyError as e:
            conn.rollback()  # Revertir la transacción en caso de error
            print("Error:", e)
        except Exception as e:
            print("Error:", e)
            
    def iterable_batch_chemy( self ):
        while True:
            rows = self.result.fetchmany(self.batch_size)
            if not rows:
                break
            yield rows
            
    def extract_data_chemy(self):
        try:
            with self.Session() as session:
                self.result = session.execute(self.__query)
                column_names = list(self.result.keys())
                for batch in self.iterable_batch_chemy():
                    pivote = pd.DataFrame(batch,columns=column_names) 
                    yield pivote
        except SQLAlchemyError as e:
            print("Error:", e)
        except Exception as e:
            print("Error:", e)
        
        
    def extract_data_all(self,batch_size=None):
        
        self.Session = sessionmaker(bind=self.engine)
        df_list =[]
        for pivote in self.extract_data_chemy():
            print(pivote.shape)
            df_list.append(pivote)  
        return pd.concat(df_list, ignore_index=True)
    
    
    def get_catalogs_(self,catalog,columns):
        cols= ','.join(columns)
        self.connect()
        try:
            df_result=None
            self.__query    =  f'Select {cols} from {catalog};'
            df_result  =  self.extract_data_all()
            #print("result:",result)
            #print("columns",columns)
            return df_result
        except CustomException as e:
            raise e
# Out:
# (10, 2)
# (10, 2)
# (5, 2)
# (10, 2)
# (10, 2)
# (5, 2)
# CATALOGO
# Error: name 'ab' is not defined
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# C:\anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     610                 query = query.encode("utf-8")
# --> 611             self._cmysql.query(
#     612                 query,
#
# MySQLInterfaceError: Cannot drop table 'CATALOGO' referenced by a foreign key constraint 'fk_PRODUCTO_CATALOGO1' on table 'PRODUCTO'.
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899                 if not evt_handled:
# -> 1900                     self.dialect.do_execute(
#    1901                         cursor, statement, parameters, context
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# C:\anaconda\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     329         try:
# --> 330             result = self._cnx.cmd_query(
#     331                 stmt,
#
# C:\anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     618         except MySQLInterfaceError as err:
# --> 619             raise get_mysql_exception(
#     620                 err.errno, msg=err.msg, sqlstate=err.sqlstate
#
# DatabaseError: 3730 (HY000): Cannot drop table 'CATALOGO' referenced by a foreign key constraint 'fk_PRODUCTO_CATALOGO1' on table 'PRODUCTO'.
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\TANIAS~1\AppData\Local\Temp/ipykernel_19352/2893873441.py in <module>
#       4 import pandas as pd
#       5 from CustomException import CustomException
# ----> 6 from CatalogUtility import CatalogUtility
#       7 from sqlalchemy import create_engine, Table, MetaData
#       8 from sqlalchemy.orm import sessionmaker
#
# D:\ProyectoTx\examenkavak\Clases\CatalogUtility.py in <module>
#       4 from CustomException import CustomException
#       5 from Catalogue import Catalogue
# ----> 6 from ConnMysql import ConnectMySQL
#       7 load_dotenv(os.path.join( os.getcwd(),'Clases/envs.txt'))
#       8
#
# D:\ProyectoTx\examenkavak\Clases\ConnMysql.py in <module>
#     257
#     258
# --> 259 objConMysql.load_data(df_cat,'CATALOGO')
#     260
#     261
#
# D:\ProyectoTx\examenkavak\Clases\ConnMysql.py in load_data(self, df, tbl_name)
#      81
#      82     def load_data(self,df, tbl_name):
# ---> 83         df.to_sql(tbl_name, self.engine , if_exists='replace')
#      84
#      85     def load_data_chemy(self,df,name_table_dest):
#
# C:\anaconda\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# C:\anaconda\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# C:\anaconda\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1749         sql_engine = get_engine(engine)
#    1750
# -> 1751         table = self.prep_table(
#    1752             frame=frame,
#    1753             name=name,
#
# C:\anaconda\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# C:\anaconda\lib\site-packages\pandas\io\sql.py in create(self)
#     858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
# --> 860                 self.pd_sql.drop_table(self.name, self.schema)
#     861                 self._execute_create()
#     862             elif self.if_exists == "append":
#
# C:\anaconda\lib\site-packages\pandas\io\sql.py in drop_table(self, table_name, schema)
#    1808         if self.has_table(table_name, schema):
#    1809             self.meta.reflect(only=[table_name], schema=schema)
# -> 1810             self.get_table(table_name, schema).drop()
#    1811             self.meta.clear()
#    1812
#
# C:\anaconda\lib\site-packages\sqlalchemy\sql\schema.py in drop(self, bind, checkfirst)
#     975         if bind is None:
#     976             bind = _bind_or_error(self)
# --> 977         bind._run_ddl_visitor(ddl.SchemaDropper, self, checkfirst=checkfirst)
#     978
#     979     @util.deprecated(
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    3226     def _run_ddl_visitor(self, visitorcallable, element, **kwargs):
#    3227         with self.begin() as conn:
# -> 3228             conn._run_ddl_visitor(visitorcallable, element, **kwargs)
#    3229
#    3230     @util.deprecated_20(
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2209
#    2210         """
# -> 2211         visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#    2212
#    2213     @util.deprecated(
#
# C:\anaconda\lib\site-packages\sqlalchemy\sql\visitors.py in traverse_single(self, obj, **kw)
#     522             meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     523             if meth:
# --> 524                 return meth(obj, **kw)
#     525
#     526     def iterate(self, obj):
#
# C:\anaconda\lib\site-packages\sqlalchemy\sql\ddl.py in visit_table(self, table, drop_ok, _is_metadata_operation, _ignore_sequences)
#    1100         )
#    1101
# -> 1102         self.connection.execute(DropTable(table))
#    1103
#    1104         # traverse client side defaults which may refer to server-side
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1378             )
#    1379         else:
# -> 1380             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1381
#    1382     def _execute_function(self, func, multiparams, params, execution_options):
#
# C:\anaconda\lib\site-packages\sqlalchemy\sql\ddl.py in _execute_on_connection(self, connection, multiparams, params, execution_options)
#      78         self, connection, multiparams, params, execution_options
#      79     ):
# ---> 80         return connection._execute_ddl(
#      81             self, multiparams, params, execution_options
#      82         )
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_ddl(self, ddl, multiparams, params, execution_options)
#    1470             dialect=dialect, schema_translate_map=schema_translate_map
#    1471         )
# -> 1472         ret = self._execute_context(
#    1473             dialect,
#    1474             dialect.execution_ctx_cls._init_ddl,
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1941
#    1942         except BaseException as e:
# -> 1943             self._handle_dbapi_exception(
#    1944                 e, statement, parameters, cursor, context
#    1945             )
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2122                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2123             elif should_wrap:
# -> 2124                 util.raise_(
#    2125                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2126                 )
#
# C:\anaconda\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206
#     207         try:
# --> 208             raise exception
#     209         finally:
#     210             # credit to
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1898                             break
#    1899                 if not evt_handled:
# -> 1900                     self.dialect.do_execute(
#    1901                         cursor, statement, parameters, context
#    1902                     )
#
# C:\anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# C:\anaconda\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     328
#     329         try:
# --> 330             result = self._cnx.cmd_query(
#     331                 stmt,
#     332                 raw=self._raw,
#
# C:\anaconda\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     617             )
#     618         except MySQLInterfaceError as err:
# --> 619             raise get_mysql_exception(
#     620                 err.errno, msg=err.msg, sqlstate=err.sqlstate
#     621             ) from err
#
# DatabaseError: (mysql.connector.errors.DatabaseError) 3730 (HY000): Cannot drop table 'CATALOGO' referenced by a foreign key constraint 'fk_PRODUCTO_CATALOGO1' on table 'PRODUCTO'.
# [SQL:
# DROP TABLE `CATALOGO`]
# (Background on this error at: https://sqlalche.me/e/14/4xp6)
